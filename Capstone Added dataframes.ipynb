# %%
#Just added dataframes together in this notebook
import pandas as pd
import numpy as np
import os
import datetime

# %%
df1 = pd.read_csv('CrimeDataCleanedreal.csv')

df1.head()
# Out:
#    Unnamed: 0        ID                 Date         Primary Type  Arrest  \
# 0           0  11034701  2001-01-01 11:00:00   DECEPTIVE PRACTICE   False
# 1           1  11227287  2017-10-08 03:00:00  CRIM SEXUAL ASSAULT   False
# 2           2  11227583  2017-03-28 14:00:00             BURGLARY   False
# 3           3  11227293  2017-09-09 20:17:00                THEFT   False
# 4           4  11227634  2017-08-26 10:00:00  CRIM SEXUAL ASSAULT   False
#
#    Domestic      Community Name   District Name
# 0     False         Avalon Park   South Chicago
# 1     False  Washington Heights     Morgan Park
# 2     False             Ashburn    Chicago Lawn
# 3     False            Woodlawn  Grand Crossing
# 4     False            The Loop         Central

# %%
df2 = pd.read_csv('ChiWeatherDataRevised.csv')

df2.head()
# Out:
#    Unnamed: 0        Date  Average Daily Wind Speed Mph  \
# 0           0  2001-01-01                          7.38
# 1           1  2001-01-02                          8.72
# 2           2  2001-01-03                         12.08
# 3           3  2001-01-04                         12.08
# 4           4  2001-01-05                         13.20
#
#    Fastest mile Wind Speed time  Peak gust time  Percipitation  Snowfall  \
# 0                          1519            1518            0.0       0.0
# 1                          1616            1614            0.0       0.0
# 2                          1101            1100            0.0       0.0
# 3                          1951            1817            0.0       0.0
# 4                          1458            1132            0.0       0.0
#
#    Snow depth  Average Temp  Max Temp  Min Temp  Fastest 2 min wind  \
# 0        17.0          20.0      26.0      13.0                15.0
# ...

# %%
df1 = df1.drop('Unnamed: 0', axis=1)
df2 = df2.drop('Unnamed: 0', axis=1)

# %%
df1.head()
# Out:
#          ID                 Date         Primary Type  Arrest  Domestic  \
# 0  11034701  2001-01-01 11:00:00   DECEPTIVE PRACTICE   False     False
# 1  11227287  2017-10-08 03:00:00  CRIM SEXUAL ASSAULT   False     False
# 2  11227583  2017-03-28 14:00:00             BURGLARY   False     False
# 3  11227293  2017-09-09 20:17:00                THEFT   False     False
# 4  11227634  2017-08-26 10:00:00  CRIM SEXUAL ASSAULT   False     False
#
#        Community Name   District Name
# 0         Avalon Park   South Chicago
# 1  Washington Heights     Morgan Park
# 2             Ashburn    Chicago Lawn
# 3            Woodlawn  Grand Crossing
# 4            The Loop         Central

# %%
df2.head()
# Out:
#          Date  Average Daily Wind Speed Mph  Fastest mile Wind Speed time  \
# 0  2001-01-01                          7.38                          1519
# 1  2001-01-02                          8.72                          1616
# 2  2001-01-03                         12.08                          1101
# 3  2001-01-04                         12.08                          1951
# 4  2001-01-05                         13.20                          1458
#
#    Peak gust time  Percipitation  Snowfall  Snow depth  Average Temp  \
# 0            1518            0.0       0.0        17.0          20.0
# 1            1614            0.0       0.0        16.0          14.0
# 2            1100            0.0       0.0        15.0          18.0
# 3            1817            0.0       0.0        14.0          28.0
# 4            1132            0.0       0.0        13.0          30.0
#
#    Max Temp  Min Temp  Fastest 2 min wind  Fastest 5 min wind  Fog/Ice Fog  \
# ...

# %%
df2.columns
# Out:
# Index(['Date', 'Average Daily Wind Speed Mph', 'Fastest mile Wind Speed time',
#        'Peak gust time', 'Percipitation', 'Snowfall', 'Snow depth',
#        'Average Temp', 'Max Temp', 'Min Temp', 'Fastest 2 min wind',
#        'Fastest 5 min wind', 'Fog/Ice Fog', 'Heavy Fog', 'Thunder', 'Hail',
#        'Smoke/Haze', 'Tornado'],
#       dtype='object')

# %%
df1_dates = df1[['ID', 'Date']]

df1_dates.head()
# Out:
#          ID                 Date
# 0  11034701  2001-01-01 11:00:00
# 1  11227287  2017-10-08 03:00:00
# 2  11227583  2017-03-28 14:00:00
# 3  11227293  2017-09-09 20:17:00
# 4  11227634  2017-08-26 10:00:00

# %%
df1_dates.shape
# Out:
# (6519152, 2)

# %%
dfs = df1_dates.merge(df2, how='outer', on='Date')

# %%
dfs.head()
# Out:
#            ID                 Date  Average Daily Wind Speed Mph  \
# 0  11034701.0  2001-01-01 11:00:00                           NaN
# 1   1310773.0  2001-01-01 11:00:00                           NaN
# 2   1310886.0  2001-01-01 11:00:00                           NaN
# 3   1311075.0  2001-01-01 11:00:00                           NaN
# 4   1311594.0  2001-01-01 11:00:00                           NaN
#
#    Fastest mile Wind Speed time  Peak gust time  Percipitation  Snowfall  \
# 0                           NaN             NaN            NaN       NaN
# 1                           NaN             NaN            NaN       NaN
# 2                           NaN             NaN            NaN       NaN
# 3                           NaN             NaN            NaN       NaN
# 4                           NaN             NaN            NaN       NaN
#
#    Snow depth  Average Temp  Max Temp  Min Temp  Fastest 2 min wind  \
# ...

# %%
dfs = dfs.sort_values(by=['Date'])

dfs.head()
# Out:
#                 ID                 Date  Average Daily Wind Speed Mph  \
# 6519152        NaN           2001-01-01                          7.38
# 7015     4735908.0  2001-01-01 00:00:00                           NaN
# 6939     1403263.0  2001-01-01 00:00:00                           NaN
# 6965     2277171.0  2001-01-01 00:00:00                           NaN
# 6967     2353946.0  2001-01-01 00:00:00                           NaN
#
#          Fastest mile Wind Speed time  Peak gust time  Percipitation  \
# 6519152                        1519.0          1518.0            0.0
# 7015                              NaN             NaN            NaN
# 6939                              NaN             NaN            NaN
# 6965                              NaN             NaN            NaN
# 6967                              NaN             NaN            NaN
#
#          Snowfall  Snow depth  Average Temp  Max Temp  Min Temp  \
# ...

# %%
dfs.shape
# Out:
# (6525359, 19)

# %%
dfs = dfs.ffill()

dfs.head(20)
# Out:
#                 ID                 Date  Average Daily Wind Speed Mph  \
# 6519152        NaN           2001-01-01                          7.38
# 7015     4735908.0  2001-01-01 00:00:00                          7.38
# 6939     1403263.0  2001-01-01 00:00:00                          7.38
# 6965     2277171.0  2001-01-01 00:00:00                          7.38
# 6967     2353946.0  2001-01-01 00:00:00                          7.38
# 6968     2393821.0  2001-01-01 00:00:00                          7.38
# 7000     3849799.0  2001-01-01 00:00:00                          7.38
# 6938     1392468.0  2001-01-01 00:00:00                          7.38
# 6937     1374123.0  2001-01-01 00:00:00                          7.38
# 6969     2429863.0  2001-01-01 00:00:00                          7.38
# 6936     1370284.0  2001-01-01 00:00:00                          7.38
# 6970     2443081.0  2001-01-01 00:00:00                          7.38
# ...

# %%
dfs.shape
# Out:
# (6525359, 19)

# %%
dfs = dfs[~dfs.Date.isin(df2.Date)]

# %%
df2.shape
# Out:
# (6207, 18)

# %%
dfs.shape
# Out:
# (6519152, 19)

# %%
dfs.head()
# Out:
#              ID                 Date  Average Daily Wind Speed Mph  \
# 7015  4735908.0  2001-01-01 00:00:00                          7.38
# 6939  1403263.0  2001-01-01 00:00:00                          7.38
# 6965  2277171.0  2001-01-01 00:00:00                          7.38
# 6967  2353946.0  2001-01-01 00:00:00                          7.38
# 6968  2393821.0  2001-01-01 00:00:00                          7.38
#
#       Fastest mile Wind Speed time  Peak gust time  Percipitation  Snowfall  \
# 7015                        1519.0          1518.0            0.0       0.0
# 6939                        1519.0          1518.0            0.0       0.0
# 6965                        1519.0          1518.0            0.0       0.0
# 6967                        1519.0          1518.0            0.0       0.0
# 6968                        1519.0          1518.0            0.0       0.0
#
#       Snow depth  Average Temp  Max Temp  Min Temp  Fastest 2 min wind  \
# ...

# %%
dfs.drop('Date', axis=1, inplace=True)

# %%
df1 = df1.sort_values(by=['Date'])

# %%
df1.head()
# Out:
#                ID                 Date                Primary Type  Arrest  \
# 16884    11109587  2001-01-01 00:00:00          DECEPTIVE PRACTICE   False
# 52318     9754963  2001-01-01 00:00:00                 SEX OFFENSE   False
# 4723505   7122679  2001-01-01 00:00:00                       THEFT   False
# 4488140   6742268  2001-01-01 00:00:00  OFFENSE INVOLVING CHILDREN   False
# 52317     9754953  2001-01-01 00:00:00                 SEX OFFENSE   False
#
#          Domestic  Community Name District Name
# 16884       False     Rogers Park   Rogers Park
# 52318       False  North Lawndale         Ogden
# 4723505     False          Uptown       Lincoln
# 4488140     False  Auburn Gresham       Gresham
# 52317       False  North Lawndale         Ogden

# %%
df = df1.merge(dfs, how='left', on='ID')

# %%
df.shape
# Out:
# (6519152, 24)

# %%
df.head(30)
# Out:
#           ID                 Date                Primary Type  Arrest  \
# 0   11109587  2001-01-01 00:00:00          DECEPTIVE PRACTICE   False
# 1    9754963  2001-01-01 00:00:00                 SEX OFFENSE   False
# 2    7122679  2001-01-01 00:00:00                       THEFT   False
# 3    6742268  2001-01-01 00:00:00  OFFENSE INVOLVING CHILDREN   False
# 4    9754953  2001-01-01 00:00:00                 SEX OFFENSE   False
# 5    3433494  2001-01-01 00:00:00                 SEX OFFENSE   False
# 6    9754946  2001-01-01 00:00:00                 SEX OFFENSE   False
# 7    9754894  2001-01-01 00:00:00                 SEX OFFENSE   False
# 8    6739668  2001-01-01 00:00:00                       THEFT   False
# 9    9755245  2001-01-01 00:00:00                 SEX OFFENSE   False
# 10   9754968  2001-01-01 00:00:00                 SEX OFFENSE   False
# 11   9755198  2001-01-01 00:00:00                 SEX OFFENSE   False
# ...

# %%
df = df.sort_values(by=['Date'])

# %%
df.to_csv('CapstonePrjoectcleandatav1.csv')

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
os.getcwd()
# Out:
# '/Users/oraff/Downloads'

# %%
df = pd.read_csv('CapstonePrjoectcleandatav1.csv')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#          ID                 Date        Primary Type  Arrest  Domestic  \
# 0  11109587  2001-01-01 00:00:00  DECEPTIVE PRACTICE   False     False
# 1   1780042  2001-01-01 00:00:00       OTHER OFFENSE   False     False
# 2   5691515  2001-01-01 00:00:00               THEFT   False     False
# 3   5233406  2001-01-01 00:00:00               THEFT    True     False
# 4   1310513  2001-01-01 00:00:00               THEFT   False     False
#
#    Community Name District Name  Average Daily Wind Speed Mph  \
# 0     Rogers Park   Rogers Park                          7.38
# 1             NaN   Morgan Park                          7.38
# 2  West Englewood     Englewood                          7.38
# 3  Near West Side     Near West                          7.38
# 4             NaN         Ogden                          7.38
#
#    Fastest mile Wind Speed time  Peak gust time  ...  Max Temp  Min Temp  \
# 0                        1519.0          1518.0  ...      26.0      13.0
# ...

# %%
df.shape
# Out:
# (6519152, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6519152 entries, 0 to 6519151
# Data columns (total 24 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   ID                            int64
#  1   Date                          object
#  2   Primary Type                  object
#  3   Arrest                        bool
#  4   Domestic                      bool
#  5   Community Name                object
#  6   District Name                 object
#  7   Average Daily Wind Speed Mph  float64
#  8   Fastest mile Wind Speed time  float64
#  9   Peak gust time                float64
#  10  Percipitation                 float64
#  11  Snowfall                      float64
#  12  Snow depth                    float64
#  13  Average Temp                  float64
#  14  Max Temp                      float64
#  15  Min Temp                      float64
#  16  Fastest 2 min wind            float64
# ...

# %%
df.describe()
# Out:
#                  ID  Average Daily Wind Speed Mph  \
# count  6.519152e+06                  6.519152e+06
# mean   6.046593e+06                  9.718156e+00
# std    2.933884e+06                  3.502246e+00
# min    6.340000e+02                  1.790000e+00
# 25%    3.355326e+06                  7.160000e+00
# 50%    6.014480e+06                  9.400000e+00
# 75%    8.578217e+06                  1.186000e+01
# max    1.199083e+07                  2.796000e+01
#
#        Fastest mile Wind Speed time  Peak gust time  Percipitation  \
# count                  6.519152e+06    6.519152e+06   6.519152e+06
# mean                   1.173115e+03    1.361800e+03   9.252878e-02
# std                    3.742398e+02    5.691705e+02   2.733740e-01
# min                    0.000000e+00    0.000000e+00   0.000000e+00
# 25%                    1.056000e+03    1.123000e+03   0.000000e+00
# 50%                    1.056000e+03    1.429000e+03   0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Primary Type', 'Arrest', 'Domestic', 'Community Name',
#        'District Name', 'Average Daily Wind Speed Mph',
#        'Fastest mile Wind Speed time', 'Peak gust time', 'Percipitation',
#        'Snowfall', 'Snow depth', 'Average Temp', 'Max Temp', 'Min Temp',
#        'Fastest 2 min wind', 'Fastest 5 min wind', 'Fog/Ice Fog', 'Heavy Fog',
#        'Thunder', 'Hail', 'Smoke/Haze', 'Tornado'],
#       dtype='object')

# %%
df.nunique()
# Out:
# ID                              6519152
# Date                            2593585
# Primary Type                         35
# Arrest                                2
# Domestic                              2
# Community Name                       77
# District Name                        22
# Average Daily Wind Speed Mph        101
# Fastest mile Wind Speed time        907
# Peak gust time                     1335
# Percipitation                       175
# Snowfall                             17
# Snow depth                           21
# Average Temp                        189
# Max Temp                            102
# Min Temp                             96
# Fastest 2 min wind                   43
# Fastest 5 min wind                   65
# Fog/Ice Fog                           2
# Heavy Fog                             2
# Thunder                               2
# Hail                                  2
# Smoke/Haze                            2
# ...

# %%
df.isnull().sum()
# Out:
# ID                                   0
# Date                                 0
# Primary Type                         0
# Arrest                               0
# Domestic                             0
# Community Name                  613577
# District Name                      234
# Average Daily Wind Speed Mph         0
# Fastest mile Wind Speed time         0
# Peak gust time                       0
# Percipitation                        0
# Snowfall                             0
# Snow depth                           0
# Average Temp                         0
# Max Temp                             0
# Min Temp                             0
# Fastest 2 min wind                   0
# Fastest 5 min wind                   0
# Fog/Ice Fog                          0
# Heavy Fog                            0
# Thunder                              0
# Hail                                 0
# Smoke/Haze                           0
# Tornado                              0
# dtype: int64

# %%
df = df.drop('Community Name', axis=1)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
#Extracting Year
df['Year'] = df['Date'].dt.year

#Extracting Month
df['Month'] = df['Date'].dt.month_name()

#Extracting the weekday name of the date
df['Day_name'] = df['Date'].dt.day_name()
        
df.head()
# Out:
#          ID       Date        Primary Type  Arrest  Domestic District Name  \
# 0  11109587 2001-01-01  DECEPTIVE PRACTICE   False     False   Rogers Park
# 1   1780042 2001-01-01       OTHER OFFENSE   False     False   Morgan Park
# 2   5691515 2001-01-01               THEFT   False     False     Englewood
# 3   5233406 2001-01-01               THEFT    True     False     Near West
# 4   1310513 2001-01-01               THEFT   False     False         Ogden
#
#    Average Daily Wind Speed Mph  Fastest mile Wind Speed time  Peak gust time  \
# 0                          7.38                        1519.0          1518.0
# 1                          7.38                        1519.0          1518.0
# 2                          7.38                        1519.0          1518.0
# 3                          7.38                        1519.0          1518.0
# 4                          7.38                        1519.0          1518.0
#
# ...

# %%
df['Fog/Ice Fog'] = df['Fog/Ice Fog'].astype(int)
df['Heavy Fog'] = df['Heavy Fog'].astype(int)
df['Thunder'] = df['Thunder'].astype(int)
df['Hail'] = df['Hail'].astype(int)
df['Smoke/Haze'] = df['Smoke/Haze'].astype(int)
df['Tornado'] = df['Tornado'].astype(int)
df['Arrest'] = df['Arrest'].astype(int)
df['Domestic'] = df['Domestic'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6519152 entries, 0 to 6519151
# Data columns (total 26 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   ID                            int64
#  1   Date                          datetime64[ns]
#  2   Primary Type                  object
#  3   Arrest                        int64
#  4   Domestic                      int64
#  5   District Name                 object
#  6   Average Daily Wind Speed Mph  float64
#  7   Fastest mile Wind Speed time  float64
#  8   Peak gust time                float64
#  9   Percipitation                 float64
#  10  Snowfall                      float64
#  11  Snow depth                    float64
#  12  Average Temp                  float64
#  13  Max Temp                      float64
#  14  Min Temp                      float64
#  15  Fastest 2 min wind            float64
#  16  Fastest 5 min wind            float64
# ...

# %%
df.head()
# Out:
#          ID       Date        Primary Type  Arrest  Domestic District Name  \
# 0  11109587 2001-01-01  DECEPTIVE PRACTICE       0         0   Rogers Park
# 1   1780042 2001-01-01       OTHER OFFENSE       0         0   Morgan Park
# 2   5691515 2001-01-01               THEFT       0         0     Englewood
# 3   5233406 2001-01-01               THEFT       1         0     Near West
# 4   1310513 2001-01-01               THEFT       0         0         Ogden
#
#    Average Daily Wind Speed Mph  Fastest mile Wind Speed time  Peak gust time  \
# 0                          7.38                        1519.0          1518.0
# 1                          7.38                        1519.0          1518.0
# 2                          7.38                        1519.0          1518.0
# 3                          7.38                        1519.0          1518.0
# 4                          7.38                        1519.0          1518.0
#
# ...

# %%
df.head()
# Out:
#          ID       Date        Primary Type  Arrest  Domestic District Name  \
# 0  11109587 2001-01-01  DECEPTIVE PRACTICE       0         0   Rogers Park
# 1   1780042 2001-01-01       OTHER OFFENSE       0         0   Morgan Park
# 2   5691515 2001-01-01               THEFT       0         0     Englewood
# 3   5233406 2001-01-01               THEFT       1         0     Near West
# 4   1310513 2001-01-01               THEFT       0         0         Ogden
#
#    Average Daily Wind Speed Mph  Fastest mile Wind Speed time  Peak gust time  \
# 0                          7.38                        1519.0          1518.0
# 1                          7.38                        1519.0          1518.0
# 2                          7.38                        1519.0          1518.0
# 3                          7.38                        1519.0          1518.0
# 4                          7.38                        1519.0          1518.0
#
# ...

# %%
df['Primary Type'].value_counts()
# Out:
# THEFT                                1362101
# BATTERY                              1188475
# CRIMINAL DAMAGE                       747121
# NARCOTICS                             699886
# OTHER OFFENSE                         403805
# ASSAULT                               400642
# BURGLARY                              377811
# MOTOR VEHICLE THEFT                   305573
# DECEPTIVE PRACTICE                    248570
# ROBBERY                               247228
# CRIMINAL TRESPASS                     187320
# PROSTITUTION                           67698
# WEAPONS VIOLATION                      65913
# PUBLIC PEACE VIOLATION                 46609
# OFFENSE INVOLVING CHILDREN             43689
# CRIM SEXUAL ASSAULT                    25953
# SEX OFFENSE                            24270
# GAMBLING                               14226
# INTERFERENCE WITH PUBLIC OFFICER       13992
# LIQUOR LAW VIOLATION                   13814
# ARSON                                  10832
# ...

# %%
df['Primary Type'].unique()
# Out:
# array(['DECEPTIVE PRACTICE', 'OTHER OFFENSE', 'THEFT',
#        'OFFENSE INVOLVING CHILDREN', 'CRIM SEXUAL ASSAULT',
#        'CRIMINAL DAMAGE', 'BATTERY', 'BURGLARY', 'ASSAULT', 'SEX OFFENSE',
#        'MOTOR VEHICLE THEFT', 'WEAPONS VIOLATION', 'CRIMINAL TRESPASS',
#        'ROBBERY', 'NARCOTICS', 'LIQUOR LAW VIOLATION',
#        'PUBLIC PEACE VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'STALKING', 'HOMICIDE', 'GAMBLING', 'KIDNAPPING', 'PROSTITUTION',
#        'INTIMIDATION', 'ARSON', 'RITUALISM', 'DOMESTIC VIOLENCE',
#        'OBSCENITY', 'OTHER NARCOTIC VIOLATION', 'PUBLIC INDECENCY',
#        'NON-CRIMINAL', 'HUMAN TRAFFICKING',
#        'NON-CRIMINAL (SUBJECT SPECIFIED)', 'NON - CRIMINAL',
#        'CONCEALED CARRY LICENSE VIOLATION'], dtype=object)

# %%
severe_crimes = ['OFFENSE INVOLVING CHILDREN', 'CRIM SEXUAL ASSAULT', 'BATTERY', 'NARCOTICS', 'BURGLARY', 'SEX OFFENSE', 'ROBBERY', 'PROSTITUTION', 'HOMICIDE', 'KIDNAPPING', 'ARSON', 'HUMAN TRAFFICKING' ]

non_severe = pd.Series(['DECEPTIVE PRACTICE', 'OTHER OFFENSE', 'THEFT', 'CRIMINAL DAMAGE', 'MOTOR VEHICLE THEFT', 'WEAPONS VIOLATION', 'CRIMINAL TRESPASS', 'ASSUALT',
             'LIQUOR LAW VIOLATION', 'PUBLIC PEACE VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER', 'STALKING', 'GAMBLING', 
              'INTIMIDATION', 'RITUALISM', 'DOMESTIC VIOLENCE', 'OBSCENITY', 'OTHER NARCOTIC VIOLATION', 'PUBLIC INDECENCY', 'NON-CRIMINAL', 'NON-CRIMINAL (SUBJECT SPECIFIED)', 'NON - CRIMINAL', 'CONCEALED CARRY LICENSE VIOLATION'])

# %%
df['Severity'] = 0

# %%
##for i in severe_crimes:
##    for index, row in df.iterrows():
 ##       row['Severity']= np.where((row['Primary Type']==i), 1, 0) 

df['Severity']= np.where((df['Primary Type']=='NARCOTICS')|(df['Primary Type']=='HOMICIDE')|(df['Primary Type']=='OFFENSE INVOLVING CHILDREN')|(df['Primary Type']=='CRIM SEXUAL ASSAULT')|(df['Primary Type']=='BATTERY')|(df['Primary Type']=='BURGLARY')|(df['Primary Type']=='SEX OFFENSE')|(df['Primary Type']=='ROBBERY')|(df['Primary Type']=='PROSTITUTION')|(df['Primary Type']=='KIDNAPPING')|(df['Primary Type']=='ARSON')|(df['Primary Type']=='HUMAN TRAFFICKING')|(df['Arrest']==1), 1, 0)

# %%
df['Hour'] = df.Date.dt.hour

# %%
df['Severity'].value_counts()
# Out:
# 1    3419505
# 0    3099647
# Name: Severity, dtype: int64

# %%
df.head(100)
# Out:
#           ID       Date                Primary Type  Arrest  Domestic  \
# 0   11109587 2001-01-01          DECEPTIVE PRACTICE       0         0
# 1    1780042 2001-01-01               OTHER OFFENSE       0         0
# 2    5691515 2001-01-01                       THEFT       0         0
# 3    5233406 2001-01-01                       THEFT       1         0
# 4    1310513 2001-01-01                       THEFT       0         0
# ..       ...        ...                         ...     ...       ...
# 95   4637483 2001-01-01                       THEFT       0         0
# 96   5785840 2001-01-01         CRIM SEXUAL ASSAULT       0         0
# 97   1352564 2001-01-01                       THEFT       0         0
# 98   9959537 2001-01-01  OFFENSE INVOLVING CHILDREN       0         1
# 99   3272413 2001-01-01                       THEFT       0         0
#
#      District Name  Average Daily Wind Speed Mph  \
# 0      Rogers Park                          7.38
# ...

# %%
df.shape
# Out:
# (6519152, 27)

# %%
correlation = df.corr()

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True, ax=ax)

# %%
df['District Name'].value_counts()
# Out:
# Chicago Lawn      445181
# Harrison          415267
# Englewood         386389
# Grand Central     378359
# Gresham           374611
# South Chicago     370544
# Grand Crossing    332681
# Deering           326166
# Near West         319277
# Wentworth         310411
# Town Hall         290303
# Calumet           288880
# Austin            285990
# Near North        282664
# Ogden             277735
# Shakespeare       258294
# Central           249003
# Jefferson Park    215968
# Morgan Park       213984
# Rogers Park       194630
# Albany Park       189188
# Lincoln           113393
# Name: District Name, dtype: int64

# %%
f, ax = plt.subplots(figsize=(25, 25))
x = pd.DataFrame(df['District Name'].value_counts())

values = list(x.index)
names = list(x['District Name'])

sns.barplot(x=values, y=names, palette="RdBu_r").set_title('All crimes')
# Out:
# Text(0.5, 1.0, 'All crimes')

# %%
df_severe = df[df.Severity != 0]

df_severe.head()
# Out:
#           ID       Date                Primary Type  Arrest  Domestic  \
# 3    5233406 2001-01-01                       THEFT       1         0
# 9    7451703 2001-01-01  OFFENSE INVOLVING CHILDREN       0         0
# 11  11513580 2001-01-01         CRIM SEXUAL ASSAULT       0         1
# 12   6110799 2001-01-01  OFFENSE INVOLVING CHILDREN       0         0
# 15   4071818 2001-01-01  OFFENSE INVOLVING CHILDREN       0         0
#
#    District Name  Average Daily Wind Speed Mph  Fastest mile Wind Speed time  \
# 3      Near West                          7.38                        1519.0
# 9        Deering                          7.38                        1519.0
# 11     Near West                          7.38                        1519.0
# 12        Austin                          7.38                        1519.0
# 15       Calumet                          7.38                        1519.0
#
#     Peak gust time  Percipitation  ...  Heavy Fog  Thunder  Hail  Smoke/Haze  \
# ...

# %%
f, ax = plt.subplots(figsize=(25, 25))
x = pd.DataFrame(df['Hour'].value_counts())

values = list(x.index)
names = list(x['Hour'])

sns.barplot(x=values, y=names, palette="RdBu_r").set_title('Hour Crimes')
# Out:
# Text(0.5, 1.0, 'Hour Crimes')

# %%
f, ax = plt.subplots(figsize=(25, 25))
x = pd.DataFrame(df_severe['Hour'].value_counts())

values = list(x.index)
names = list(x['Hour'])

sns.barplot(x=values, y=names, palette="RdBu_r").set_title('Severe Crimes')
# Out:
# Text(0.5, 1.0, 'Severe Crimes')

# %%
df_severe['District Name'].value_counts()
# Out:
# Harrison          283154
# Englewood         234411
# Chicago Lawn      219632
# Gresham           208109
# Grand Central     202868
# Austin            192972
# South Chicago     192946
# Grand Crossing    190518
# Deering           178287
# Wentworth         170561
# Ogden             164987
# Calumet           162251
# Near West         146343
# Town Hall         123442
# Shakespeare       115728
# Near North        113850
# Central           103213
# Morgan Park       102316
# Rogers Park        92945
# Albany Park        84979
# Jefferson Park     83283
# Lincoln            52585
# Name: District Name, dtype: int64

# %%
f, ax = plt.subplots(figsize=(25, 25))
x = pd.DataFrame(df_severe['District Name'].value_counts())

values = list(x.index)
names = list(x['District Name'])

sns.barplot(x=values, y=names, palette="RdBu_r").set_title('Severe Crimes')
# Out:
# Text(0.5, 1.0, 'Severe Crimes')

# %%
f, ax = plt.subplots(figsize=(50, 20))
x = pd.DataFrame(df['Primary Type'].value_counts())

values = list(x.index)
names = list(x['Primary Type'])

sns.barplot(x=values, y=names, palette="RdBu_r").set_title('Severe Crimes')
# Out:
# Text(0.5, 1.0, 'Severe Crimes')

# %%
f, ax = plt.subplots(figsize=(50, 20))
x = pd.DataFrame(df_severe['Primary Type'].value_counts())

values = list(x.index)
names = list(x['Primary Type'])

sns.barplot(x=values, y=names, palette="RdBu_r").set_title('Severe Crimes')
# Out:
# Text(0.5, 1.0, 'Severe Crimes')

# %%
dims = (20, 10)
fig, ax = plt.subplots(figsize=dims)

sns.distplot(df_severe['Average Temp'], bins=100, ax=ax)

# %%
dims = (20, 10)
fig, ax = plt.subplots(figsize=dims)

sns.distplot(df['Average Temp'], bins=100, ax=ax)

# %%
## Added weather data to compare see number of days that are certain temperatures.
df_w = pd.read_csv('ChiWeatherDataRevised.csv')

df_w.head()
# Out:
#    Unnamed: 0        Date  Average Daily Wind Speed Mph  \
# 0           0  2001-01-01                          7.38
# 1           1  2001-01-02                          8.72
# 2           2  2001-01-03                         12.08
# 3           3  2001-01-04                         12.08
# 4           4  2001-01-05                         13.20
#
#    Fastest mile Wind Speed time  Peak gust time  Percipitation  Snowfall  \
# 0                          1519            1518            0.0       0.0
# 1                          1616            1614            0.0       0.0
# 2                          1101            1100            0.0       0.0
# 3                          1951            1817            0.0       0.0
# 4                          1458            1132            0.0       0.0
#
#    Snow depth  Average Temp  Max Temp  Min Temp  Fastest 2 min wind  \
# 0        17.0          20.0      26.0      13.0                15.0
# ...

# %%
df_w = df_w.drop('Unnamed: 0', axis=1)

# %%
Q1 = df_w.quantile(.25)
Q3 = df_w.quantile(.75)
IQR = Q3 - Q1

dfno = df_w[~((df_w < (Q1 - 1.5 * IQR)) |(df_w> (Q3 + 1.5 * IQR))).any(axis=1)]
dfnoplt = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
dims = (20, 10)
fig, ax = plt.subplots(figsize=dims)

sns.distplot(df_w['Average Temp'], bins=100, ax=ax)

# %%
sns.boxplot(df['Severity'], df['Average Temp'])

# %%
sns.relplot(x = 'Average Daily Wind Speed Mph', y = 'Average Temp', hue='Severity', data=df, height=8)

# %%
sns.distplot(df['Average Daily Wind Speed Mph'], bins=60)

# %%
sns.distplot(df_severe['Average Daily Wind Speed Mph'], bins=60)

# %%
sns.distplot(df_w['Average Daily Wind Speed Mph'], bins=60)

# %%
sns.distplot(df['Percipitation'])

# %%
df.to_csv('AfterEDAChiCrime.csv')
